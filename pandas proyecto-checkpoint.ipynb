# %%
# !pip install sqlalchemy pymysql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns

usuario = "root"
contraseña = "1234"
host = "localhost"
puerto = 3306
base_de_datos = "employeesurvey"

connection_string = f"mysql+pymysql://{usuario}:{contraseña}@{host}:{puerto}/{base_de_datos}"
engine = create_engine(connection_string)

df = pd.read_sql("SELECT * FROM encuesta", engine)

df.info()         # Muestra tipos de columna (int, float, object, etc.)
pd.set_option('display.float_format', '{:.2f}'.format)
df.describe()     # Estadísticas numéricas básicas


ax = df['Age'].hist(
    bins=10,
    figsize=(6,4),
    edgecolor='black',
    grid=False  # Desactiva la cuadrícula
)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()


# Supongamos que tienes un DataFrame llamado df con estas columnas:
# 'satisfacción_laboral', 'estrés', 'género', 'categoría_laboral', 'sector'

# Gráfico 1: Comparar la satisfacción laboral según género
df.groupby('Gender')['JobSatisfaction'].mean().plot(
    kind='bar', figsize=(8, 6), color='skyblue', edgecolor='black')
plt.title('Job satisfaction by gender')
plt.xlabel('Gender')
plt.ylabel('Avarage job satisfaction')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Gráfico 2: Nivel de estrés según género
df.groupby('Gender')['Stress'].mean().plot(
    kind='bar', figsize=(8, 6), color='lightcoral', edgecolor='black')
plt.title('Levels of stress by gender')
plt.xlabel('Gender')
plt.ylabel('Avarage level of stress')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Gráfico 3: Nivel de estrés según categoría laboral
df.groupby('JobLevel')['Stress'].mean().plot(
    kind='bar', figsize=(8, 6), color='mediumseagreen', edgecolor='black')
plt.title('Levels of stress by job level')
plt.xlabel('Job Level')
plt.ylabel('Avarage level of stress')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Gráfico 4: Nivel de estrés según sector
df.groupby('Dept')['Stress'].mean().plot(
    kind='bar', figsize=(8, 6), color='gold', edgecolor='black')
plt.title('Level of stress by department')
plt.xlabel('Department')
plt.ylabel('Avarage level of stress')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

print(df.columns)
print("Columnas disponibles en df_encoded:", df_encoded.columns)

# Convertir variables categóricas a numéricas si es necesario
# Esto es útil para correlaciones si aún no lo has hecho
categorical_columns = ['MaritalStatus', 'EmpType', 'CommuteMode', 'EduLevel']
df_encoded = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Crear una matriz de correlación para las variables seleccionadas
variables_of_interest = [
    'Age', 'JobSatisfaction', 'Stress', 'CommuteMode', 
    'PhysicalActivityHours', 'WLB', 'Workload', 'WorkEnv']

correlation_matrix = df_encoded[variables_of_interest].corr()

# Visualizar la matriz de correlación como un heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Age with Key Variables')
plt.show()

# Relación específica: Diagrama de dispersión entre Edad y Satisfacción Laboral
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='JobSatisfaction', hue='Gender', palette='viridis')
plt.title('Age vs Job Satisfaction')
plt.xlabel('Age')
plt.ylabel('Job Satisfaction')
plt.grid(alpha=0.7)
plt.show()

# Relación específica: Diagrama de dispersión entre Edad y Nivel de Estrés
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='Stress', hue='EmpType', palette='muted')
plt.title('Age vs Stress Level')
plt.xlabel('Age')
plt.ylabel('Stress Level')
plt.grid(alpha=0.7)
plt.show()
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025 entries, 0 to 3024
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmpID                  3025 non-null   int64
#  1   Gender                 3025 non-null   object
#  2   Age                    3025 non-null   int64
#  3   MaritalStatus          3025 non-null   object
#  4   JobLevel               3025 non-null   object
#  5   Experience             3025 non-null   int64
#  6   Dept                   3025 non-null   object
#  7   EmpType                3025 non-null   object
#  8   WLB                    3025 non-null   int64
#  9   WorkEnv                3025 non-null   int64
#  10  PhysicalActivityHours  3025 non-null   float64
#  11  Workload               3025 non-null   int64
#  12  Stress                 3025 non-null   int64
#  13  SleepHours             3025 non-null   float64
# ...
